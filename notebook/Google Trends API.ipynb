# %%
# !pip install pytrends
import pandas
import numpy as np
# Out:
# Requirement already satisfied: pytrends in /opt/conda/lib/python3.7/site-packages (4.7.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.7/site-packages (from pytrends) (4.5.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from pytrends) (1.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from pytrends) (2.23.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from pandas->pytrends) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas->pytrends) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->pytrends) (2019.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->pytrends) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->pytrends) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->pytrends) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->pytrends) (1.14.0)

# %%
pytrend = TrendReq(hl='zh-TW', tz=360)
keywords = ['Azure','GCP','AWS']
pytrend.build_payload(
     kw_list=keywords,
     cat=0,
     timeframe='today 3-m',
     geo='TW',
     gprop='')

# %%
pytrend.interest_over_time().plot()

# %%
data=pytrends.get_historical_interest(keywords, year_start=2020,
                                 month_start=1, day_start=1, 
                                 hour_start=0, year_end=2020, 
                                 month_end=2, day_end=1, 
                                 hour_end=0, cat=0, geo='TW', gprop='', sleep=0)
data.plot()

# %%
pytrends.interest_by_region(resolution='COUNTRY', inc_low_vol=True, inc_geo_code=False)
# Out:
#          Azure  GCP  AWS
# geoName
# 台中市         31   24   45
# 台北市         30   19   51
# 台南市         37   20   43
# 新北市         34   14   52
# 桃園市         36   12   52
# 高雄市         45   14   41

# %%
pytrends.related_topics()
# Out:
# {}

# %%
pytrends.related_queries()['Azure']['top']
# Out:
#                 query  value
# 0     microsoft azure    100
# 1           microsoft    100
# 2        azure portal     61
# 3        azure devops     58
# 4            azure ad     49
# 5                 aws     44
# 6            azure 教學     31
# 7            azure 中文     26
# 8            微軟 azure     22
# 9                 gcp     21
# 10             github     16
# 11         office 365     16
# 12     azure notebook     14
# 13       azure sphere     11
# 14          azure 計算機     11
# 15           azure 發音     11
# 16  azure data studio     10
# 17         azure 是 什麼     10
# 18         azure pass      9
# 19               azur      8

# %%
pytrends.related_queries()['GCP']['top']
# Out:
#                    query  value
# 0             google gcp    100
# 1            gcp console     70
# 2                    aws     63
# 3                 gcp 課程     37
# 4                  azure     35
# 5                 gcp 教學     30
# 6  google cloud platform     22
# 7                gcp ssr     13
# 8                godaddy      5
# 9                 heroku      5

# %%
pytrends.related_queries()['AWS']['top']
# Out:
#                 query  value
# 0             aws ec2    100
# 1              aws s3     94
# 2          amazon aws     78
# 3              amazon     78
# 4         aws educate     60
# 5          aws lambda     52
# 6              lambda     52
# 7         aws console     50
# 8             aws cli     50
# 9               azure     44
# 10             aws 台灣     43
# 11             aws 教學     42
# 12            aws rds     41
# 13                rds     41
# 14                gcp     37
# 15            aws iot     37
# 16             github     25
# 17  aws certification     23
# 18            aws ecs     21
# 19                ecs     21
# 20           aws 是 什麼     19
# 21                k8s     16
# 22             aws 證照     14
# 23       aws training     14
# 24         aws status     14

# %%
pytrends.suggestions('azure')
# Out:
# [{'mid': '/m/04y7lrx', 'title': 'Microsoft Azure', 'type': '主題'},
#  {'mid': '/m/03wbldj', 'title': 'Microsoft Azure SQL Database', 'type': '主題'},
#  {'mid': '/m/03jn2m', 'title': '天蓝色', 'type': '主題'},
#  {'mid': '/m/0b2h7k', 'title': '宾利Azure', 'type': '汽车模特'},
#  {'mid': '/m/026zbl4', 'title': 'Vuze', 'type': '主題'}]

# %%
top_charts_df = pytrend.top_charts(2019, hl='zh-TW', tz=300, geo='TW')
top_charts_df
# Out:
#           title        exploreQuery
# 0       我們與惡的距離         我們 與 惡 的 距離
# 1            颱風
# 2      世界12強棒球賽
# 3         小女花不棄            小女 花 不 棄
# 4           韓國瑜
# 5          長榮罷工
# 6  知否？知否？應是綠肥紅瘦  知 否 知 否 應 是 綠肥 紅 瘦
# 7           皓鑭傳               皓 鑭 傳
# 8            小丑
# 9         德魯納酒店            德 魯 納 酒店

# %%
pytrends.trending_searches(pn='taiwan')
# Out:
#                0
# 0          克羅埃西亞
# 1             梁天
# 2            王定宇
# 3            張上淳
# 4             奎寧
# 5   Jamal Murray
# 6            N號房
# 7            曾之喬
# 8            悠遊付
# 9            李來希
# 10          案124
# 11           周遊記
# 12          屏東確診
# 13          案156
# 14           劉香慈
# 15           陳學聖
# 16           黃明志
# 17           江宏傑
# 18          假偶天成
# 19           梁靜茹
