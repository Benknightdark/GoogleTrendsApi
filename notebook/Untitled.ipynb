# %%
# !pip install pytrends
import pandas
import numpy as np 
import time

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['武漢肺炎'],geo='TW')
# Interest by Region
df = pytrend.interest_by_region()
df.head(10)
# Out:
#                  武漢肺炎
# geoName
# Kaohsiung City      0
# New Taipei City     0
# Taichung City       0
# Tainan City         0
# Taipei City         0
# Taoyuan City        0

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = ['DejaVu Sans']

df.reset_index().plot(x='geoName', y='武漢 肺炎', figsize=(120, 10), kind ='bar')

# %%
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='taiwan')
df.head()
# Out:
#        0
# 0  克羅埃西亞
# 1     梁天
# 2    王定宇
# 3    張上淳
# 4     奎寧

# %%
df = pytrend.today_searches(pn='taiwan')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-59-7e48888e0c35> in <module>
# ----> 1 df = pytrend.today_searches(pn='taiwan')
#
# /opt/conda/lib/python3.7/site-packages/pytrends/request.py in today_searches(self, pn)
#     413             method=TrendReq.GET_METHOD,
#     414             trim_chars=5,
# --> 415             params=forms
#     416         )['default']['trendingSearchesDays'][0]['trendingSearches']
#     417         result_df = pd.DataFrame()
#
# /opt/conda/lib/python3.7/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     144                 'The request failed: Google returned a '
#     145                 'response with code {0}.'.format(response.status_code),
# --> 146                 response=response)
#     147
#     148     def build_payload(self, kw_list, cat=0, timeframe='today 5-y', geo='',
#
# ...

# %%
df = pytrend.top_charts(2019, hl='zh-TW', tz=300, geo='GLOBAL')
df.head()
# Out:
#                    title exploreQuery
# 0  India vs South Africa
# 1          Cameron Boyce
# 2           Copa America
# 3    Bangladesh vs India
# 4              iPhone 11

# %%
keywords = pytrend.suggestions(keyword='Mercedes Benz')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense
# Out:
#                      title                type
# 0            Mercedes-Benz  Automobile company
# 1    Mercedes-Benz A-Class           Car model
# 2            Mercedes-Benz     Automobile make
# 3  Mercedes-Benz GLC-Class    Automobile model
# 4    Mercedes-Benz E-Class           Car model

# %%
pytrend.build_payload(kw_list=['武漢肺炎'])

# %%
# Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':           query  value
# 0         武漢 肺炎    100
# 1            武漢    100
# 2            肺炎    100
# 3      武漢 肺炎 台灣     14
# 4         武漢 疫情     10
# 5      武漢 肺炎 疫情     10
# 6            疫情     10
# 7         肺炎 症狀      8
# 8      武漢 肺炎 症狀      8
# 9      武漢 肺炎 最新      5
# 10     武漢 肺炎 確診      5
# 11     武漢 肺炎 病徵      4
# 12     日本 武漢 肺炎      3
# 13  最新 武漢 肺炎 疫情      3
# 14     武漢 肺炎 人數      3
# 15  台灣 武漢 肺炎 確診      2
# 16    武漢 肺炎 ptt      2
# 17   武漢 肺炎 分佈 圖      2
# 18     武漢 肺炎 口罩      2
# 19           口罩      2
# 20  武漢 肺炎 最新 情況      2
# 21     武漢 肺炎 病毒      2
# 22     武漢 肺炎 韓國      2
# 23        武漢 病毒      2
# 24     武漢 肺炎 死亡      2, 'rising':           query    value
# 0         武漢 肺炎  9999900
# 1            武漢  9999900
# 2            肺炎  9999900
# 3      武漢 肺炎 台灣  1367850
# 4         武漢 疫情  1046000
# 5      武漢 肺炎 疫情  1036550
# 6            疫情  1022500
# 7         肺炎 症狀   792150
# 8      武漢 肺炎 症狀   750400
# 9      武漢 肺炎 最新   548800
# ...

# %%
# Related Topics, returns a dictionary of dataframes
related_topic = pytrend.related_topics()
related_topic
# Out:
# {'武漢肺炎': {'rising':       value formattedValue                                               link  \
#   0   9999900       Breakout   /trends/explore?q=/m/0dq9p&date=today+5-y&geo=TW
#   1   8716650       Breakout   /trends/explore?q=/m/0l3cy&date=today+5-y&geo=TW
#   2   1209500       Breakout  /trends/explore?q=/m/01b_06&date=today+5-y&geo=TW
#   3    213650       Breakout  /trends/explore?q=/m/04b_zc&date=today+5-y&geo=TW
#   4    181600       Breakout   /trends/explore?q=/m/0g9pc&date=today+5-y&geo=TW
#   5    143900       Breakout   /trends/explore?q=/m/098s1&date=today+5-y&geo=TW
#   6     99000       Breakout  /trends/explore?q=/m/01byzl&date=today+5-y&geo=TW
#   7     96550       Breakout  /trends/explore?q=/m/01b_21&date=today+5-y&geo=TW
#   8     92500       Breakout  /trends/explore?q=/m/01cpyy&date=today+5-y&geo=TW
#   9     90300       Breakout   /trends/explore?q=/m/069q9&date=today+5-y&geo=TW
# ...

# %%
pList=[]
for keywords in ['關鍵字']:
    print(keywords)
    keywords_list=[keywords]
    sleep_sec=np.random.randint(3,5)
    time.sleep(sleep_sec)
    
    pytrend.build_payload(keywords_list,cat=0,timeframe='today 5-y',geo='TW',gprop='')
    interest_over_time_df=pytrend.interest_over_time()
    pList.append(keywords)
# Out:
# 關鍵字
